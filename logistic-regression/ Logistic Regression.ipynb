# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data= pd.read_csv("sample.csv")
data.head()
# Out:
#    age  job
# 0   16    0
# 1   24    0
# 2   31    1
# 3   29    0
# 4   40    1

# %%
plt.scatter(data.age,data.job)

# %%
x = data[["age"]]      # as show 2d array in x variable's values
x
# Out:
#     age
# 0    16
# 1    24
# 2    31
# 3    29
# 4    40
# 5    33
# 6    18
# 7    36
# 8    15
# 9    37
# 10   19
# 11   21
# 12   29
# 13   31
# 14   23
# 15   20
# 16   34
# 17   22
# 18   32
# 19   15
# 20   14
# 21   13
# 22   51
# 23   43
# 24   23
# 25   31

# %%
y = data["job"]
y
# Out:
# 0     0
# 1     0
# 2     1
# 3     0
# 4     1
# 5     0
# 6     0
# 7     1
# 8     0
# 9     1
# 10    0
# 11    0
# 12    1
# 13    1
# 14    1
# 15    0
# 16    1
# 17    0
# 18    1
# 19    0
# 20    0
# 21    0
# 22    1
# 23    1
# 24    0
# 25    1
# Name: job, dtype: int64

# %% [markdown]
# ## create model

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size =0.2)

# %%
x_train
# Out:
#     age
# 1    24
# 9    37
# 16   34
# 18   32
# 12   29
# 5    33
# 20   14
# 17   22
# 22   51
# 8    15
# 10   19
# 11   21
# 2    31
# 19   15
# 13   31
# 25   31
# 6    18
# 3    29
# 21   13
# 15   20

# %%
len(x_train)
# Out:
# 20

# %%
len(x_test)
# Out:
# 6

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()     # create model object

# %%
model.fit(x_train,y_train)      # train the model
# Out:
# LogisticRegression()

# %%
model.predict(x_test)    # test the model
# Out:
# array([1, 1, 1, 0, 0, 0], dtype=int64)

# %%
x_test
# Out:
#     age
# 23   43
# 7    36
# 4    40
# 14   23
# 24   23
# 0    16

# %%
y_test
# Out:
# 23    1
# 7     1
# 4     1
# 14    1
# 24    0
# 0     0
# Name: job, dtype: int64

# %%
model.score(x_test,y_test)
# Out:
# 0.8333333333333334

# %%
age = [[29]]
model.predict(age)
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
ages = np.array([[31],[20],[33]])
model.predict(ages)
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1, 0, 1], dtype=int64)
